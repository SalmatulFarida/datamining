# %% [markdown]
# # Liner Regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=20, n_features=1, noise=10)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([258.08345638])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
# python code demonstrate creating
# dataframe from dict narrat/lists
# by default addresses

import pandas as pd
data = {'X': x,
        'Y': y}
# create dataframe
df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                          X           Y
# 0     [0.6015998112510358]   16.941578
# 1    [-0.9079126680810404]  -66.696098
# 2     [0.8229404585254906]   68.049105
# 3   [-0.12394887043820867]    8.034432
# 4     [1.2220873359560949]  110.092164
# 5     [-1.044742719913127]  -79.345151
# 6   [-0.45508061836846025]  -46.089424
# 7    [-1.1035701785340586]  -94.376262
# 8     [0.6397802138254958]   59.220293
# 9      [1.259960991408557]   97.070241
# 10    [0.6823978108833093]   61.442872
# 11   [-1.4142451205637299] -117.804541
# 12  [-0.27466433538778257]  -21.007938
# 13   [0.37637752672299646]   22.331526
# 14   [-1.4188267922292555] -118.077699
# 15    [2.6577064999646827]  245.814315
# 16   [0.23080004568483617]    7.353147
# 17    [0.7386184819353379]   78.399575
# 18      [1.80061598292472]  153.964257
# 19    [0.3438477396141084]   46.364019

# %%
reg.coef_
# Out:
# array([85.4308897])

# %%
reg.intercept_
# Out:
# 1.7907872847344102

# %%
pyplot.scatter(X_test,y_test)
Y_plot = reg.coef_*X_test+reg.intercept_
pyplot.plot(X_test, Y_plot, color='r')
pyplot.show()
