# %% [markdown]
# # Liner Regression

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=20, n_features=1, noise=10)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([25.36067699])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
# python code demonstrate creating
# dataframe from dict narrat/lists
# by default addresses

import pandas as pd
data = {'X': x,
        'Y': y}
# create dataframe
df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                          X          Y
# 0    [-0.9378726768774943]   9.659144
# 1     [0.4343611405691883]   6.978104
# 2     [-0.848715962012408]  -1.725915
# 3     [1.2007194310232805]  18.483809
# 4     [0.7955115548357525]  -0.063871
# 5    [-0.5738059707675497] -12.812700
# 6    [-0.6883512405621337] -14.664776
# 7     [1.1328352628920009]   7.668872
# 8    [-0.6313972521346993] -16.748733
# 9    [-0.7631279420460222] -12.754266
# 10   [-0.4566949966381879]  -6.636552
# 11    [1.1521810811772397]  11.195787
# 12  [-0.22237236416129133]  -2.806824
# 13   [-1.2917041372174984]  -8.110457
# 14  [-0.06418149845094741] -16.094025
# 15   [-0.9495401548434121] -12.749254
# 16     [-0.97196563570975]   2.997243
# 17   [-0.9601322051723407] -13.600050
# 18  [-0.17521415039053953]  14.066538
# 19   [-0.3876810546604177]  15.399710

# %%
reg.coef_
# Out:
# array([8.27411971])

# %%
reg.intercept_
# Out:
# 0.5383178500488048

# %%
pyplot.scatter(X_test,y_test)
Y_plot = reg.coef_*X_test+reg.intercept_
pyplot.plot(X_test, Y_plot, color='r')
pyplot.show()
