# %% [markdown]
# # Liner Regression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from matplotlib import pyplot
X_test, y_test = make_regression(n_samples=20, n_features=1, noise=10)
reg = LinearRegression().fit(X_test, y_test)
reg.score(X_test, y_test)

reg.coef_

reg.intercept_

reg.predict(np.array([[3]]))
# Out:
# array([141.80904444])

# %%
x=X_test.tolist()
y=y_test.tolist()

# %%
# python code demonstrate creating
# dataframe from dict narrat/lists
# by default addresses

import pandas as pd
data = {'X': x,
        'Y': y}
# create dataframe
df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                           X          Y
# 0   [-0.021609898370735212] -11.474360
# 1    [-0.33413779022694207] -35.711016
# 2      [0.5322522200245786]  29.606051
# 3     [-0.6774570182495568] -26.906585
# 4    [0.015624872340576688]   4.079067
# 5      [-0.546565741819477] -28.980213
# 6      [1.1400671130580493]  58.603397
# 7      [0.6718733438542202]  44.528144
# 8     [-0.6647856493847955] -27.017348
# 9     [-1.5711782548636448] -80.647144
# 10    [-0.7757049880231127] -47.171164
# 11    [-0.8540251104690852] -30.601118
# 12     [0.2599980638854995]  19.551544
# 13     [0.9130656336039075]  44.070410
# 14     [1.7147771208380918]  68.745005
# 15     [0.5771422685643864]  31.752990
# 16    [-0.1655394772345233] -10.715614
# 17    [-0.7104345069438166] -11.535740
# 18  [0.0068782309293826905]   5.479748
# 19     [0.2787523361952208]  10.377979

# %%
reg.coef_
# Out:
# array([47.00381188])

# %%
reg.intercept_
# Out:
# 0.7976087968227747

# %%
pyplot.scatter(X_test,y_test)
Y_plot = reg.coef_*X_test+reg.intercept_
pyplot.plot(X_test, Y_plot, color='r')
pyplot.show()
